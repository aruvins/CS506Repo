# %% [markdown]
# # Worksheet 02
#
# Name: Aidan Ruvins
# UID: U98270572
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# Don't have runnable code until the end

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# Have to know everything up front

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# - Read the error
# - Re-read your code
# - Sanity check where you can

# %% [markdown]
# d) Follow along with the live coding. You can write your code here:

# %%
class Board:
  def __init__(self):
    self.Board = [["_" for _ in range(8)] for _ in range(8)]

  def __repr__(self):
    res = ""
    for row in self.Board:
      for col in row:
        res += col
        res += " "
      res += "\n"
    return res

  def is_legal_row(self,row,col):
    for j in range(len(self.Board)):
      if self.Board[row][j] == "Q":
        return False
    return True

  def is_legal_col(self,row,col):
    for i in range(len(self.Board)):
      if self.Board[i][col] == "Q":
        return False
    return True

  def is_on_board(self,row,col):
    return row >= 0 and row<8 and col >=0 and col < 8

  def is_legal_diag(self,row,col):
    for i in range(len(self.Board)):
      if self.is_on_board(row - i, col - i) and Board[row - i][col - i] == "Q":
        return False
      if self.is_on_board(row - i, col + i) and Board[row - i][col - i] == "Q":
        return False
      if self.is_on_board(row + i, col - i) and Board[row - i][col - i] == "Q":
        return False
      if self.is_on_board(row + i, col + i) and Board[row - i][col - i] == "Q":
        return False
    return True

  def is_legal (self, row, col):
    if not self.is_legal_row(row,col):
      return False
    if not self.is_legal_col(row,col):
      return False
    if not self.is_legal_diag(row,col):
      return False
    return True

  def set_queen_at (self,row, col):
    self.Board[row][col] = "Q"

  def unset_queen_on(self,row):
    self.Board[row] = ["_" for _ in range[8]]

  def get_queen_on(self,row):
    for col in range(len(self.Board)):
      if self.Board[row][col] == "Q":
        return col

  def search(self):
    row = 0
    col = 0
    while row < 8:
      if self.is_legal(row, col):
        self.set_queen_at(row,col)
        row += 1
        col = 0
      else:
        col += 1
        while col >= 8:
          col = self.get_queen_on(row-1)
          self.unset_queen_on(row - 1)
          col += 1
          row -= 1

    print("solution found")
    print(Board)

my_board = Board()
my_board.search()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-8f43a996bc4d> in <cell line: 81>()
#      79
#      80 my_board = Board()
# ---> 81 my_board.search()
#
# <ipython-input-32-8f43a996bc4d> in search(self)
#      63     col = 0
#      64     while row < 8:
# ---> 65       if self.is_legal(row, col):
#      66         self.set_queen_at(row,col)
#      67         row += 1
#
# <ipython-input-32-8f43a996bc4d> in is_legal(self, row, col)
#      44     if not self.is_legal_col(row,col):
#      45       return False
# ---> 46     if not self.is_legal_diag(row,col):
#      47       return False
#      48     return True
#
# <ipython-input-32-8f43a996bc4d> in is_legal_diag(self, row, col)
#      29   def is_legal_diag(self,row,col):
#      30     for i in range(len(self.Board)):
# ---> 31       if self.is_on_board(row - i, col - i) and Board[row - i][col - i] == "Q":
# ...
